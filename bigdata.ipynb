# %%
#extraccion de datos con pandas 

#importacion de pandas
import pandas as pd

# %%
#cargar el csv
df = pd.read_csv("centros-de-atencion-veterinaria.csv")
#mostrar las primeras cinco filas
df.head()
# Out:
#          long         lat tipo_atencion        dias          horarios  \
# 0  -58,496986  -34,668574         MOVIL  2018-08-07      9 a 14:30 hs
# 1  -58,388311  -34,626081         MOVIL  2018-08-10   8:15 a 14:30 hs
# 2  -58,406886  -34,625913         MOVIL  2018-08-10   8:15 a 14:30 hs
# 3  -58,474991  -34,645153         MOVIL  2018-08-10   8:15 a 14:30 hs
# 4  -58,492992  -34,605509         MOVIL  2018-08-11  10:30 a 17:30 hs
#
#                  direccion                       lugar             barrio  \
# 0          Monte y Amancay                  Contededor          Mataderos
# 1  Pavon y Virrey Cevallos                 Plaza Garay       Constitución
# 2    La Rioja y Cochabamba         Plaza Martin Fierro      San Cristobal
# 3    Fco. Bilbao y Lacarra           Parque Avellaneda  Parque Avellaneda
# 4              Cuenca 2500  Plaza Aristobulo del Valle   Villa del Parque
#
#    comuna                                   consultas
# ...

# %%
#mostrar la cantidad de filas y columnas
print(df.shape)

#mostrar los nombres de las columnas
print(df.columns)

#mostrar los tipos de datos qe hay en cada columna
print(df.dtypes)

#vista
print(df.info())
# Out:
# (19, 10)
# Index(['long', 'lat', 'tipo_atencion', 'dias', 'horarios', 'direccion',
#        'lugar', 'barrio', 'comuna', 'consultas'],
#       dtype='object')
# long             object
# lat              object
# tipo_atencion    object
# dias             object
# horarios         object
# direccion        object
# lugar            object
# barrio           object
# comuna            int64
# consultas        object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   long           19 non-null     object
#  1   lat            19 non-null     object
#  2   tipo_atencion  19 non-null     object
#  3   dias           19 non-null     object
#  4   horarios       19 non-null     object
#  5   direccion      19 non-null     object
#  6   lugar          19 non-null     object
#  7   barrio         19 non-null     object
# ...

# %%
#cuantos datos son nulos
df.isnull()
# Out:
#      long    lat  tipo_atencion   dias  horarios  direccion  lugar  barrio  \
# 0   False  False          False  False     False      False  False   False
# 1   False  False          False  False     False      False  False   False
# 2   False  False          False  False     False      False  False   False
# 3   False  False          False  False     False      False  False   False
# 4   False  False          False  False     False      False  False   False
# 5   False  False          False  False     False      False  False   False
# 6   False  False          False  False     False      False  False   False
# 7   False  False          False  False     False      False  False   False
# 8   False  False          False  False     False      False  False   False
# 9   False  False          False  False     False      False  False   False
# 10  False  False          False  False     False      False  False   False
# ...

# %%
#mostrar cantidad de valores nulos por columna

print(df.isnull().sum())
# Out:
# long             0
# lat              0
# tipo_atencion    0
# dias             0
# horarios         0
# direccion        0
# lugar            0
# barrio           0
# comuna           0
# consultas        0
# dtype: int64

# %%
#estos datos ya estan limpios por los qe vamos directamente a estadisticas descriptivas

#mostrar estadisticas

print(df.describe())
# Out:
#           comuna
# count  19.000000
# mean    8.631579
# std     4.716526
# min     1.000000
# 25%     5.000000
# 50%     9.000000
# 75%    12.000000
# max    15.000000

# %%
#visualizamos los datos con matplotlib
import matplotlib.pyplot as plt

# %%
# Agrupamos por día y contamos cuántos centros hay cada día
centros_por_dia = df['dias'].value_counts().sort_index()

# Tamaño de la figura
plt.figure(figsize=(10, 5))

# Título y etiquetas
plt.title("Cantidad de centros de atención por día")
plt.plot(centros_por_dia.index, centros_por_dia.values)
plt.xlabel("Fecha")
plt.ylabel("Cantidad de centros")
plt.xticks(rotation=20)
plt.grid()

# %%
# Contamos cuántas veces aparece cada tipo de consulta
consultas_conteo = df['consultas'].value_counts()

# Gráfico de torta
plt.figure(figsize=(7, 7))
plt.pie(
    consultas_conteo.values,
    labels=consultas_conteo.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=plt.cm.Paired.colors  # Paleta linda y clara
)
plt.title('Distribución de Tipos de Consultas')
plt.axis('equal')  # Para que sea perfectamente redondo
plt.tight_layout()
plt.show()

# %%
# Conteo de cada horario exacto
horarios_conteo = df['horarios'].value_counts()

# Gráfico de torta
plt.figure(figsize=(7, 7))
plt.pie(
    horarios_conteo.values,
    labels=horarios_conteo.index,
    autopct='%1.1f%%',
    startangle=90
)
plt.title('Distribución de Horarios Exactos')
plt.axis('equal')
plt.xticks(rotation=20)  # gira etiquetas si hace falta
plt.tight_layout()
plt.show()
